# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('../driver/chromedriver')
driver.get("http://naver.com")

# %%
driver.save_screenshot('../Images/001.jpg')
# Out:
# /Users/jh/opt/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py:1030: UserWarning: name used for saved screenshot does not match file type. It should end with a `.png` extension
#   warnings.warn("name used for saved screenshot does not match file "
# True

# %%
'''
elem_login = driver.find_element_by_id('id')
elem_login.clear()
elem_login.send_keys('kjh960215')

elem_login = driver.find_element_by_id('pw')
elem_login.clear()
elem_login.send_keys('rlawngP1226')
'''
driver.get("https://nid.naver.com/nidlogin.login?mode=form&amp;url=https%3A%2F%2Fwww.naver.com")

# %%
elem_login = driver.find_element_by_id('id')
elem_login.clear()
elem_login.send_keys("kjh960215")

elem_login = driver.find_element_by_id('pw')
elem_login.clear()
elem_login.send_keys("pw")

# %%
xpath = """//*[@id="log.login"]"""
driver.find_element_by_xpath(xpath).click()

# %%
driver.get("http://mail.naver.com")

# %%
from bs4 import BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <html lang="ko"><head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/css/mail2_le.min.200716.css" rel="stylesheet" type="text/css"/>
# <link href="/css/mail_skin.min.200716.css" rel="stylesheet" type="text/css"/>
# <link href="//ssl.pstatic.net" rel="dns-prefetch"/>
# <link href="//lcs.naver.com" rel="dns-prefetch"/>
# <link href="//cc.naver.com" rel="dns-prefetch"/>
# <link href="//static.nid.naver.com" rel="dns-prefetch"/>
# <link href="//phinf.pstatic.net" rel="dns-prefetch"/>
# <link href="/css/mail_me.min.200716.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico?2" rel="shortcut icon"/>
# <title>받은메일함(17086) : 네이버 메일</title>
# <script type="text/javascript">
#
#
#
# 		var gnb_service = "mail";
# 		var gnb_logout = "http://www.naver.com";
# 		var gnb_template = "gnb_utf8";
# 		var gnb_brightness = 3;
# 		var gnb_item_hide_option = 8;
# 		var gnb_one_naver = 1;
#
#
# ...

# %%
raw_list = soup.find_all('div','mTitle', 'name _ccr(lst.from) ')
raw_list
# Out:
# [<div class="mTitle"><div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|34062) _stopDefault" href="#" title='"CodePen" &lt;support@codepen.io&gt;'>CodePen</a></div><div class="subject"><a class="_d2(mcDragndrop|html5DragStart)" draggable="true" href="/read/popup/?nMailId=34062"><span class="text _ccr(lst.title) _c1(mrCore|clickTitle|34062) _m2(mrCore|middleClickTitle|34062)" foldersn="" mailsn="34062"><span class="folderName _ccr(lst.title) _c1(mrCore|clickTitle|34062) _m2(mrCore|middleClickTitle|34062)" foldersn="" mailsn="34062"><span class="blind">에 분류됨</span></span><strong class="mail_title _ccr(lst.title) _c1(mrCore|clickTitle|34062) _m2(mrCore|middleClickTitle|34062)" foldersn="" mailsn="34062"><span class="blind">메일 제목:</span>The CodePen Spark: Pinwheels, Pups, and Perlin Noise</strong></span></a><a class="icon_previewMail" href="#" title="메일 내용 미리보기"><span class="spr _m1(mlCore|previewMail|34062|0) _c1(mlCo
# ...

# %%
send_list = [raw_list[n].find('a').get_text() for n in range(0, len(raw_list))]
send_list
# Out:
# ['CodePen',
#  '사람인 | 추천',
#  '사람인 | 추천',
#  '예스24(콩편지)',
#  '뮤직카우',
#  '사람인 | 나의 검색',
#  '텐바이텐',
#  '예스24(이벤트)',
#  '캐치ㅣ속보',
#  '크라우드픽',
#  '창업신문',
#  'Apple',
#  '예스24(다락편지)',
#  '사람인 | 신입공채',
#  '사람인 | 추천',
#  '사람인 | 추천',
#  '쿠팡',
#  'NHN KCP <발신전..',
#  '크몽 [IT 카테고리 팀]',
#  '머스트잇',
#  '사람인 | 나의 검색',
#  '한양대학교학술정보..',
#  '예스24(문화산책)',
#  '캐치ㅣ속보',
#  '사람인 | 추천',
#  '사람인 | 추천',
#  'KG이니시스',
#  '텐바이텐',
#  '사람인 | 나의 검색',
#  '캐치ㅣ속보',
#  '예스24(콕편지)',
#  '이벤트메일',
#  'T WORLD',
#  '예스24(콕편지)',
#  '스타트업 찾기 ',
#  '위즈위드',
#  '사람인 | 추천',
#  '사람인 | 추천',
#  '한양대학교',
#  'CATCH',
#  '한양대학교',
#  '예스24(공연)',
#  'IC-PBL교수학습센..',
#  '예스24(웹소설/코믹..',
#  '사람인 | 나의 검색',
#  'G마켓',
#  '신한카드',
#  '위즈위드',
#  '캐치ㅣ속보',
#  'NEWNEEK',
#  '텀블벅 tumblbug',
#  '사람인 | 추천',
#  '리얼클래스',
#  '사람인 | 추천',
#  '패스트캠퍼스',
#  '한양대학교',
#  '쿠팡',
#  'Unity Technologies',
#  '네이버 캘린더 알림',
#  '네이버 캘린더 알림',
#  '사람인 | 나의 검색',
#  '와디즈 뉴스레터',
#  '예스24(영화)',
#  'G마켓 스마일페이',
#  'Apple',
#  '캐치ㅣ추천',
#  '한양대학교',
#  '캐치ㅣ속보',
# ...

# %%
driver.close()

# %%
driver = webdriver.Chrome('../driver/chromedriver')
driver.get("http://www.opinet.co.kr/searRgSelect.do")

# %%
gu_list_raw = driver.find_element_by_xpath('''//*[@id="SIGUNGU_NM0"]''')
gu_list = gu_list_raw.find_elements_by_tag_name('option')
gu_list
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="0d6554da52fec8758d7b2daf5bca59ff", element="ac19e2b3-c864-4454-a0d7-4da8a33486f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0d6554da52fec8758d7b2daf5bca59ff", element="d8cfc75f-54f4-4f8c-9fec-ba13334950ce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0d6554da52fec8758d7b2daf5bca59ff", element="86b73d37-7925-4636-b8fd-db252d0a2924")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0d6554da52fec8758d7b2daf5bca59ff", element="32c95181-b935-4732-9f87-c2306fc8b34a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0d6554da52fec8758d7b2daf5bca59ff", element="f20e59a6-833d-4d1a-b92c-90410f7793ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0d6554da52fec8758d7b2daf5bca59ff", element="043580ce-6ddd-4856-abac-71e54cc5ebed")>,
# ...

# %%
gu_names = [option.get_attribute('value') for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
element = driver.find_element_by_id('SIGUNGU_NM0')
element.send_keys(gu_names[0])

# %%
xpath = '''//*[@id="searRgSelect"]'''
element_sel_gu = driver.find_element_by_xpath(xpath).click()

# %%
xpath = '''//*[@id="glopopd_excel"]'''
element_get_excel = driver.find_element_by_xpath(xpath).click()
